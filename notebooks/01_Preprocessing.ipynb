# %% [markdown]
# ## Title

# %%
# ==================================================
# 01_Data_Preparation.ipynb
# Fake News Detection - Data Preparation
# ==================================================

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

from data_processing.preprocess import load_data
from data_processing.clean_text import clean_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 from data_processing.preprocess import load_data
#       4 from data_processing.clean_text import clean_text
#
# ModuleNotFoundError: No module named 'data_processing'

# %% [markdown]
# ## Load Dataset

# %%
# Load merged dataset

df = load_data()

print("Dataset Shape:")
print(df.shape)

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Load merged dataset
# ----> 3 df = load_data()
#       5 print("Dataset Shape:")
#       6 print(df.shape)
#
# NameError: name 'load_data' is not defined
