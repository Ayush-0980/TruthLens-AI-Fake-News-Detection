# %%
news = [
    "Breaking: Aliens have taken over the White House"
]

vector = tfidf.transform(news)

prediction = svm_model.predict(vector)

print(prediction)
# Out:
# [0]

# %%
news = [
    "Scientists discover water on Mars"
]

vector = tfidf.transform(news)

prediction = svm_model.predict(vector)

print(prediction)
# Out:
# [1]
